# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('dark_background')
pd.set_option('display.float_format', '{:.4f}'.format)

df = pd.read_csv("../data/creditcard.csv")
print(f"Dataset chargé : {df.shape[0]:,} transactions, {df.shape[1]} colonnes")
# Out:
# Dataset chargé : 284,807 transactions, 31 colonnes

# %%
df.head(5)
df.info()
df[["Time", "Amount", "Class"]].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 df.head(5)
# ----> 2 pythondf.info()
#       3 pythondf[["Time", "Amount", "Class"]].describe()
#
# NameError: name 'pythondf' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 de.head(5)
#       2 df.infos()
#       3 df[["Time", "Amount", "Class"]].describe()
#
# NameError: name 'de' is not defined
